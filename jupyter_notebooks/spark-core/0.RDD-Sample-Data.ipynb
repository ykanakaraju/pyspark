# %%
# %run "Setup-App.ipynb"

# %%
sc
# Out:
# <SparkContext master=local[*] appName=Wordcount Application>

# %%
rdd1 = sc.parallelize([3,4,5,6,3,2,1,4,3,5,6,7,8,9,0,8,9,0,8,9,0,3,4,2,1,3,2,4,3,5,6,7], 3)

# %%
rddFile = sc.textFile("E:\\Spark\\wordcount.txt", 4)

# %%
rdd2 = rdd1.map(lambda x: (x, x%4))

# %%
rddWords = rddFile.flatMap(lambda x: x.split())

# %%
rddWords.collect()
# Out:
# ['hadoop',
#  'spark',
#  'scala',
#  'flatmap',
#  'map',
#  'groupby',
#  'spark',
#  'spark',
#  'hadoop',
#  'scala',
#  'flume',
#  'oozie',
#  'sqoop',
#  'hive',
#  'hive',
#  'spark',
#  'spark',
#  'mapreduce',
#  'hadoop',
#  'hive',
#  'hadoop',
#  'hdfs',
#  'flatmap',
#  'rdd',
#  'scala',
#  'spark',
#  'scala',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'rdd',
#  'spark',
#  'scala',
#  'rdd',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'hadoop',
#  'spark',
#  'scala',
#  'flatmap',
#  'map',
#  'groupby',
#  'spark',
#  'spark',
#  'hadoop',
#  'scala',
#  'flume',
#  'oozie',
#  'sqoop',
#  'hive',
#  'hive',
#  'spark',
#  'spark',
#  'mapreduce',
#  'hadoop',
#  'hive',
#  'hadoop',
#  'hdfs',
#  'flatmap',
#  'rdd',
#  'scala',
#  'spark',
#  'scala',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'rdd',
#  'spark',
#  'scala',
#  'rdd',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'hadoop',
#  'spark',
#  'scala',
#  'flatmap',
#  'map',
#  'groupby',
#  'spark',
#  'spark',
#  'hadoop',
#  'scala',
#  'flume',
#  'oozie',
#  'sqoop',
#  'hive',
#  'hive',
#  'spark',
#  'spark',
#  'mapreduce',
#  'hadoop',
#  'hive',
#  'hadoop',
#  'hdfs',
#  'flatmap',
#  'rdd',
#  'scala',
#  'spark',
#  'scala',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'rdd',
#  'hadoop',
#  'spark',
#  'scala',
#  'flatmap',
#  'map',
#  'groupby',
#  'spark',
#  'spark',
#  'hadoop',
#  'scala',
#  'flume',
#  'oozie',
#  'sqoop',
#  'hive',
#  'hive',
#  'spark',
#  'spark',
#  'mapreduce',
#  'hadoop',
#  'hive',
#  'hadoop',
#  'hdfs',
#  'flatmap',
#  'rdd',
#  'scala',
#  'spark',
#  'scala',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'rdd',
#  'spark',
#  'scala',
#  'rdd',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'hadoop',
#  'spark',
#  'scala',
#  'flatmap',
#  'map',
#  'groupby',
#  'spark',
#  'spark',
#  'hadoop',
#  'scala',
#  'flume',
#  'oozie',
#  'sqoop',
#  'hive',
#  'hive',
#  'spark',
#  'spark',
#  'mapreduce',
#  'hadoop',
#  'hive',
#  'hadoop',
#  'hdfs',
#  'flatmap',
#  'rdd',
#  'scala',
#  'spark',
#  'scala',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'rdd',
#  'spark',
#  'scala',
#  'rdd',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'hadoop',
#  'spark',
#  'scala',
#  'flatmap',
#  'map',
#  'groupby',
#  'spark',
#  'spark',
#  'hadoop',
#  'scala',
#  'flume',
#  'oozie',
#  'sqoop',
#  'hive',
#  'hive',
#  'spark',
#  'spark',
#  'mapreduce',
#  'hadoop',
#  'hive',
#  'hadoop',
#  'hdfs',
#  'flatmap',
#  'rdd',
#  'scala',
#  'spark',
#  'scala',
#  'transformations',
#  'actions',
#  'rdd',
#  'hadoop',
#  'hive',
#  'asd',
#  'sadas',
#  'das',
#  'das',
#  'das',
#  'das',
#  'das',
#  'das',
#  'd',
#  'asd',
#  'asd',
#  'asd',
#  'asd',
#  'hadoop',
#  'scala',
#  'flume',
#  'oozie',
#  'sqoop',
#  'hive',
#  'hive',
#  'spark',
#  'spark',
#  'mapreduce',
#  'hadoop',
#  'hive',
#  'hadoop',
#  'hdfs',
#  'flatmap',
#  'rdd',
#  'scala',
#  'spark',
#  'scala',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'rdd',
#  'hadoop',
#  'spark',
#  'scala',
#  'flatmap',
#  'map',
#  'groupby',
#  'spark',
#  'spark',
#  'hadoop',
#  'scala',
#  'flume',
#  'oozie',
#  'sqoop',
#  'hive',
#  'hive',
#  'spark',
#  'spark',
#  'mapreduce',
#  'hadoop',
#  'hive',
#  'hadoop',
#  'hdfs',
#  'flatmap',
#  'rdd',
#  'scala',
#  'spark',
#  'scala',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'rdd',
#  'spark',
#  'scala',
#  'rdd',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'hadoop',
#  'spark',
#  'scala',
#  'flatmap',
#  'map',
#  'groupby',
#  'spark',
#  'spark',
#  'hadoop',
#  'scala',
#  'flume',
#  'oozie',
#  'sqoop',
#  'hive',
#  'hive',
#  'spark',
#  'spark',
#  'mapreduce',
#  'hadoop',
#  'hive',
#  'hadoop',
#  'hdfs',
#  'flatmap',
#  'rdd',
#  'scala',
#  'spark',
#  'scala',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'rdd',
#  'spark',
#  'scala',
#  'rdd',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'hadoop',
#  'spark',
#  'scala',
#  'flatmap',
#  'map',
#  'groupby',
#  'spark',
#  'spark',
#  'hadoop',
#  'scala',
#  'flume',
#  'oozie',
#  'sqoop',
#  'hive',
#  'hive',
#  'spark',
#  'spark',
#  'mapreduce',
#  'hadoop',
#  'hive',
#  'hadoop',
#  'hdfs',
#  'flatmap',
#  'rdd',
#  'scala',
#  'spark',
#  'scala',
#  'transformations',
#  'actions',
#  'rdd',
#  'hadoop',
#  'hive',
#  'asd',
#  'sadas',
#  'das',
#  'das',
#  'das',
#  'das',
#  'das',
#  'das',
#  'd',
#  'asd',
#  'asd',
#  'asd',
#  'asd']
