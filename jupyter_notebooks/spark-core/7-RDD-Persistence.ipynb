# %%
# %run "0.RDD-Sample-Data.ipynb"

# %%
sc

# %%
rddWords.collect()

# %%
rddWords.toDebugString()

# %%
rddWords.persist()
# rddWords.cache()

# %%
rddWords.toDebugString()

# %%
rddWords.collect()

# %%
rddWords.collect()

# %%
rddWords.collect()

# %%
rddWords.unpersist()

# %%
rddWords.collect()

# %%
from pyspark import StorageLevel

# %%
rddWords.persist(StorageLevel.DISK_ONLY)
# Out:
# PythonRDD[3] at collect at C:\Users\ADMIN\AppData\Local\Temp\ipykernel_14508\999693240.py:1

# %%
rddWords.toDebugString()
# Out:
# b'(4) PythonRDD[3] at collect at C:\\Users\\ADMIN\\AppData\\Local\\Temp\\ipykernel_14508\\999693240.py:1 [Disk Serialized 1x Replicated]\n |  E:\\Spark\\wordcount.txt MapPartitionsRDD[2] at textFile at NativeMethodAccessorImpl.java:0 [Disk Serialized 1x Replicated]\n |  E:\\Spark\\wordcount.txt HadoopRDD[1] at textFile at NativeMethodAccessorImpl.java:0 [Disk Serialized 1x Replicated]'

# %%
rddWords.collect()
# Out:
# ['hadoop',
#  'spark',
#  'scala',
#  'flatmap',
#  'map',
#  'groupby',
#  'spark',
#  'spark',
#  'hadoop',
#  'scala',
#  'flume',
#  'oozie',
#  'sqoop',
#  'hive',
#  'hive',
#  'spark',
#  'spark',
#  'mapreduce',
#  'hadoop',
#  'hive',
#  'hadoop',
#  'hdfs',
#  'flatmap',
#  'rdd',
#  'scala',
#  'spark',
#  'scala',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'rdd',
#  'spark',
#  'scala',
#  'rdd',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'hadoop',
#  'spark',
#  'scala',
#  'flatmap',
#  'map',
#  'groupby',
#  'spark',
#  'spark',
#  'hadoop',
#  'scala',
#  'flume',
#  'oozie',
#  'sqoop',
#  'hive',
#  'hive',
#  'spark',
#  'spark',
#  'mapreduce',
#  'hadoop',
#  'hive',
#  'hadoop',
#  'hdfs',
#  'flatmap',
#  'rdd',
#  'scala',
#  'spark',
#  'scala',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'rdd',
#  'spark',
#  'scala',
#  'rdd',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'hadoop',
#  'spark',
#  'scala',
#  'flatmap',
#  'map',
#  'groupby',
#  'spark',
#  'spark',
#  'hadoop',
#  'scala',
#  'flume',
#  'oozie',
#  'sqoop',
#  'hive',
#  'hive',
#  'spark',
#  'spark',
#  'mapreduce',
#  'hadoop',
#  'hive',
#  'hadoop',
#  'hdfs',
#  'flatmap',
#  'rdd',
#  'scala',
#  'spark',
#  'scala',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'rdd',
#  'hadoop',
#  'spark',
#  'scala',
#  'flatmap',
#  'map',
#  'groupby',
#  'spark',
#  'spark',
#  'hadoop',
#  'scala',
#  'flume',
#  'oozie',
#  'sqoop',
#  'hive',
#  'hive',
#  'spark',
#  'spark',
#  'mapreduce',
#  'hadoop',
#  'hive',
#  'hadoop',
#  'hdfs',
#  'flatmap',
#  'rdd',
#  'scala',
#  'spark',
#  'scala',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'rdd',
#  'spark',
#  'scala',
#  'rdd',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'hadoop',
#  'spark',
#  'scala',
#  'flatmap',
#  'map',
#  'groupby',
#  'spark',
#  'spark',
#  'hadoop',
#  'scala',
#  'flume',
#  'oozie',
#  'sqoop',
#  'hive',
#  'hive',
#  'spark',
#  'spark',
#  'mapreduce',
#  'hadoop',
#  'hive',
#  'hadoop',
#  'hdfs',
#  'flatmap',
#  'rdd',
#  'scala',
#  'spark',
#  'scala',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'rdd',
#  'spark',
#  'scala',
#  'rdd',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'hadoop',
#  'spark',
#  'scala',
#  'flatmap',
#  'map',
#  'groupby',
#  'spark',
#  'spark',
#  'hadoop',
#  'scala',
#  'flume',
#  'oozie',
#  'sqoop',
#  'hive',
#  'hive',
#  'spark',
#  'spark',
#  'mapreduce',
#  'hadoop',
#  'hive',
#  'hadoop',
#  'hdfs',
#  'flatmap',
#  'rdd',
#  'scala',
#  'spark',
#  'scala',
#  'transformations',
#  'actions',
#  'rdd',
#  'hadoop',
#  'hive',
#  'asd',
#  'sadas',
#  'das',
#  'das',
#  'das',
#  'das',
#  'das',
#  'das',
#  'd',
#  'asd',
#  'asd',
#  'asd',
#  'asd',
#  'hadoop',
#  'scala',
#  'flume',
#  'oozie',
#  'sqoop',
#  'hive',
#  'hive',
#  'spark',
#  'spark',
#  'mapreduce',
#  'hadoop',
#  'hive',
#  'hadoop',
#  'hdfs',
#  'flatmap',
#  'rdd',
#  'scala',
#  'spark',
#  'scala',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'rdd',
#  'hadoop',
#  'spark',
#  'scala',
#  'flatmap',
#  'map',
#  'groupby',
#  'spark',
#  'spark',
#  'hadoop',
#  'scala',
#  'flume',
#  'oozie',
#  'sqoop',
#  'hive',
#  'hive',
#  'spark',
#  'spark',
#  'mapreduce',
#  'hadoop',
#  'hive',
#  'hadoop',
#  'hdfs',
#  'flatmap',
#  'rdd',
#  'scala',
#  'spark',
#  'scala',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'rdd',
#  'spark',
#  'scala',
#  'rdd',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'hadoop',
#  'spark',
#  'scala',
#  'flatmap',
#  'map',
#  'groupby',
#  'spark',
#  'spark',
#  'hadoop',
#  'scala',
#  'flume',
#  'oozie',
#  'sqoop',
#  'hive',
#  'hive',
#  'spark',
#  'spark',
#  'mapreduce',
#  'hadoop',
#  'hive',
#  'hadoop',
#  'hdfs',
#  'flatmap',
#  'rdd',
#  'scala',
#  'spark',
#  'scala',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'rdd',
#  'spark',
#  'scala',
#  'rdd',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'hadoop',
#  'spark',
#  'scala',
#  'flatmap',
#  'map',
#  'groupby',
#  'spark',
#  'spark',
#  'hadoop',
#  'scala',
#  'flume',
#  'oozie',
#  'sqoop',
#  'hive',
#  'hive',
#  'spark',
#  'spark',
#  'mapreduce',
#  'hadoop',
#  'hive',
#  'hadoop',
#  'hdfs',
#  'flatmap',
#  'rdd',
#  'scala',
#  'spark',
#  'scala',
#  'transformations',
#  'actions',
#  'rdd',
#  'hadoop',
#  'hive',
#  'asd',
#  'sadas',
#  'das',
#  'das',
#  'das',
#  'das',
#  'das',
#  'das',
#  'd',
#  'asd',
#  'asd',
#  'asd',
#  'asd']

# %%
rddWords.collect()
# Out:
# ['hadoop',
#  'spark',
#  'scala',
#  'flatmap',
#  'map',
#  'groupby',
#  'spark',
#  'spark',
#  'hadoop',
#  'scala',
#  'flume',
#  'oozie',
#  'sqoop',
#  'hive',
#  'hive',
#  'spark',
#  'spark',
#  'mapreduce',
#  'hadoop',
#  'hive',
#  'hadoop',
#  'hdfs',
#  'flatmap',
#  'rdd',
#  'scala',
#  'spark',
#  'scala',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'rdd',
#  'spark',
#  'scala',
#  'rdd',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'hadoop',
#  'spark',
#  'scala',
#  'flatmap',
#  'map',
#  'groupby',
#  'spark',
#  'spark',
#  'hadoop',
#  'scala',
#  'flume',
#  'oozie',
#  'sqoop',
#  'hive',
#  'hive',
#  'spark',
#  'spark',
#  'mapreduce',
#  'hadoop',
#  'hive',
#  'hadoop',
#  'hdfs',
#  'flatmap',
#  'rdd',
#  'scala',
#  'spark',
#  'scala',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'rdd',
#  'spark',
#  'scala',
#  'rdd',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'hadoop',
#  'spark',
#  'scala',
#  'flatmap',
#  'map',
#  'groupby',
#  'spark',
#  'spark',
#  'hadoop',
#  'scala',
#  'flume',
#  'oozie',
#  'sqoop',
#  'hive',
#  'hive',
#  'spark',
#  'spark',
#  'mapreduce',
#  'hadoop',
#  'hive',
#  'hadoop',
#  'hdfs',
#  'flatmap',
#  'rdd',
#  'scala',
#  'spark',
#  'scala',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'rdd',
#  'hadoop',
#  'spark',
#  'scala',
#  'flatmap',
#  'map',
#  'groupby',
#  'spark',
#  'spark',
#  'hadoop',
#  'scala',
#  'flume',
#  'oozie',
#  'sqoop',
#  'hive',
#  'hive',
#  'spark',
#  'spark',
#  'mapreduce',
#  'hadoop',
#  'hive',
#  'hadoop',
#  'hdfs',
#  'flatmap',
#  'rdd',
#  'scala',
#  'spark',
#  'scala',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'rdd',
#  'spark',
#  'scala',
#  'rdd',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'hadoop',
#  'spark',
#  'scala',
#  'flatmap',
#  'map',
#  'groupby',
#  'spark',
#  'spark',
#  'hadoop',
#  'scala',
#  'flume',
#  'oozie',
#  'sqoop',
#  'hive',
#  'hive',
#  'spark',
#  'spark',
#  'mapreduce',
#  'hadoop',
#  'hive',
#  'hadoop',
#  'hdfs',
#  'flatmap',
#  'rdd',
#  'scala',
#  'spark',
#  'scala',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'rdd',
#  'spark',
#  'scala',
#  'rdd',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'hadoop',
#  'spark',
#  'scala',
#  'flatmap',
#  'map',
#  'groupby',
#  'spark',
#  'spark',
#  'hadoop',
#  'scala',
#  'flume',
#  'oozie',
#  'sqoop',
#  'hive',
#  'hive',
#  'spark',
#  'spark',
#  'mapreduce',
#  'hadoop',
#  'hive',
#  'hadoop',
#  'hdfs',
#  'flatmap',
#  'rdd',
#  'scala',
#  'spark',
#  'scala',
#  'transformations',
#  'actions',
#  'rdd',
#  'hadoop',
#  'hive',
#  'asd',
#  'sadas',
#  'das',
#  'das',
#  'das',
#  'das',
#  'das',
#  'das',
#  'd',
#  'asd',
#  'asd',
#  'asd',
#  'asd',
#  'hadoop',
#  'scala',
#  'flume',
#  'oozie',
#  'sqoop',
#  'hive',
#  'hive',
#  'spark',
#  'spark',
#  'mapreduce',
#  'hadoop',
#  'hive',
#  'hadoop',
#  'hdfs',
#  'flatmap',
#  'rdd',
#  'scala',
#  'spark',
#  'scala',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'rdd',
#  'hadoop',
#  'spark',
#  'scala',
#  'flatmap',
#  'map',
#  'groupby',
#  'spark',
#  'spark',
#  'hadoop',
#  'scala',
#  'flume',
#  'oozie',
#  'sqoop',
#  'hive',
#  'hive',
#  'spark',
#  'spark',
#  'mapreduce',
#  'hadoop',
#  'hive',
#  'hadoop',
#  'hdfs',
#  'flatmap',
#  'rdd',
#  'scala',
#  'spark',
#  'scala',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'rdd',
#  'spark',
#  'scala',
#  'rdd',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'hadoop',
#  'spark',
#  'scala',
#  'flatmap',
#  'map',
#  'groupby',
#  'spark',
#  'spark',
#  'hadoop',
#  'scala',
#  'flume',
#  'oozie',
#  'sqoop',
#  'hive',
#  'hive',
#  'spark',
#  'spark',
#  'mapreduce',
#  'hadoop',
#  'hive',
#  'hadoop',
#  'hdfs',
#  'flatmap',
#  'rdd',
#  'scala',
#  'spark',
#  'scala',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'rdd',
#  'spark',
#  'scala',
#  'rdd',
#  'transformations',
#  'actions',
#  'rdd',
#  'rdd',
#  'rdd',
#  'hadoop',
#  'spark',
#  'scala',
#  'flatmap',
#  'map',
#  'groupby',
#  'spark',
#  'spark',
#  'hadoop',
#  'scala',
#  'flume',
#  'oozie',
#  'sqoop',
#  'hive',
#  'hive',
#  'spark',
#  'spark',
#  'mapreduce',
#  'hadoop',
#  'hive',
#  'hadoop',
#  'hdfs',
#  'flatmap',
#  'rdd',
#  'scala',
#  'spark',
#  'scala',
#  'transformations',
#  'actions',
#  'rdd',
#  'hadoop',
#  'hive',
#  'asd',
#  'sadas',
#  'das',
#  'das',
#  'das',
#  'das',
#  'das',
#  'das',
#  'd',
#  'asd',
#  'asd',
#  'asd',
#  'asd']

# %%
rddWords.unpersist()
# Out:
# PythonRDD[3] at collect at C:\Users\ADMIN\AppData\Local\Temp\ipykernel_14508\999693240.py:1
