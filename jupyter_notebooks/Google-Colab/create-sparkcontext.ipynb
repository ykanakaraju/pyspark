# %% [markdown]
# ## Create a Spark Context

# %% [markdown]
# #### Mount your Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# #### Install and setup PySpark

# %%
# %run "/content/drive/MyDrive/Colab Notebooks/PySpark/Spark-Core-RDD/setup-pyspark.ipynb"

# %% [markdown]
# #### Create a SparkContext object

# %%
from pyspark import SparkContext

sc = SparkContext(appName="Spark RDD Application")

# %%
print("SparkContext object called 'sc' created")
