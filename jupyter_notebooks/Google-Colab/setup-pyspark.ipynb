# %% [markdown]
# ## Install and Setup PySpark

# %%
# !sudo apt update
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
#Check this site for the latest download link https://www.apache.org/dyn/closer.lua/spark/spark-3.2.1/spark-3.2.1-bin-hadoop3.2.tgz
# !wget -q https://archive.apache.org/dist/spark/spark-3.5.7/spark-3.5.7-bin-hadoop3.tgz
# !tar xf spark-3.5.7-bin-hadoop3.tgz
# !pip install -q findspark
# !pip install pyspark
# !pip install py4j

# %%
print("Java OpenJDK-8 installed")
print("Spark 3.5.7 Downloaded")
print("findspark library installed")
print("PySpark installed")
print("Py4J installed")

# %%
import os
import sys
# os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
# os.environ["SPARK_HOME"] = "/content/spark-3.2.1-bin-hadoop3.2"
import findspark
findspark.init()
findspark.find()

# %%
print("findspark imported and is working")
